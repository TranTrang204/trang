# %% [markdown]
# <a href="https://colab.research.google.com/github/TranTrang204/trang/blob/main/untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pandas

# %%
import pandas as pd

# Read data from CSV files
df_customer_table = pd.read_csv('customer_table.csv')
df_market_trend = pd.read_csv('market_trend.csv')
df_product_detail = pd.read_csv('product_detail.csv')
df_sale_table = pd.read_csv('sale_table.csv')
df_website_access_category = pd.read_csv('website_access_category.csv')

print("customer_table Data:\n", df_customer_table.head())
print("\nmarket_trend Data:\n", df_market_trend.head())
print("\nproduct_detail:\n", df_product_detail.head())
print("\nsale_table Data:\n", df_sale_table.head())
print("\nwebsite_access_category Data:\n", df_website_access_category.head())
# Out:
# customer_table Data:
#     CustomerID    CustomerName                      Email       Phone  \
# 0          31    Grace Turner    graceturner@example.com  6665554444
# 1          32  Dylan Mitchell  dylanmitchell@example.com  3332221111
# 2          33        Ava Ward        avaward@example.com  8887776666
# 3          34     Liam Cooper     liamcooper@example.com  5554443333
# 4          35   Sophie Turner   sophieturner@example.com  2221110000
#
#          Address         City State Country  PostalCode RegistrationDate
# 0     123 Elm St      Seattle    WA     USA     54321.0       2024-07-15
# 1   456 Pine Ave  Los Angeles    CA     USA     98765.0       2024-08-30
# 2     789 Oak St        Miami    FL     USA     12345.0       2024-09-10
# 3   321 Maple Ln      Chicago    IL     USA     67890.0       2024-10-25
# 4  654 Birch Ave     New York    NY     USA     54321.0       2024-11-05
#
# market_trend Data:
# ...

# %%
pip install matplotlib

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read data from CSV files
df_customer_table = pd.read_csv('customer_table.csv')
df_market_trend = pd.read_csv('market_trend.csv')
df_product_detail = pd.read_csv('product_detail.csv')
df_sale_table = pd.read_csv('sale_table.csv')
df_website_access_category = pd.read_csv('website_access_category.csv')

#  Scatter Plot: Revenue vs. Quantity Sold
plt.figure(figsize=(15, 4))
# Adjust scatter plot
plt.scatter(df_sale_table['Quantity'], df_sale_table['TotalPrice'], color='darkorange', edgecolor='black', alpha=0.7, s=100)
# Adjust axis labels and titles
plt.xlabel('Quantity', fontsize=14, fontweight='bold')
plt.ylabel('TotalPrice', fontsize=14, fontweight='bold')
plt.title('Quantity vs.TotalPrice', fontsize=16, fontweight='bold')
# Add grid with line style
plt.grid(True, linestyle='--', alpha=0.7)
# Adjust ticks
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read data from CSV files
df_customer_table = pd.read_csv('customer_table.csv')
df_market_trend = pd.read_csv('market_trend.csv')
df_product_detail = pd.read_csv('product_detail.csv')
df_sale_table = pd.read_csv('sale_table.csv')
df_website_access_category = pd.read_csv('website_access_category.csv')

# Corrected DataFrame reference
customer_table = df_customer_table['PostalCode'].value_counts()

# Create a pie chart
plt.figure(figsize=(20, 5))
plt.pie(
    customer_table,
    labels=customer_table.index,
    autopct='%1.1f%%',
    colors=['yellow', 'red', 'green', 'blue']
)
plt.title('PostalCode')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read data from CSV files
df_customer_table = pd.read_csv('customer_table.csv')
df_market_trend = pd.read_csv('market_trend.csv')
df_product_detail = pd.read_csv('product_detail.csv')
df_sale_table = pd.read_csv('sale_table.csv')
df_website_access_category = pd.read_csv('website_access_category.csv')

# Histogram
plt.figure(figsize=(20, 6))
plt.hist(
    df_market_trend['MarketTrend'],
    bins=15,
    color='skyblue',
    edgecolor='white',
    alpha=0.8  #
)
plt.xlabel('MarketTrend', fontsize=14, fontweight='bold', color='darkblue')
plt.ylabel('Description', fontsize=14, fontweight='bold', color='darkblue')
plt.title('Description of MarketTrend', fontsize=18, fontweight='bold', color='navy')
plt.grid(True, linestyle=':', color='gray', alpha=0.7)
plt.xticks(fontsize=12, color='darkblue')
plt.yticks(fontsize=12, color='darkblue')
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read data from CSV files
df_customer_table = pd.read_csv('customer_table.csv')
df_market_trend = pd.read_csv('market_trend.csv')
df_product_detail = pd.read_csv('product_detail.csv')
df_sale_table = pd.read_csv('sale_table.csv')
df_website_access_category = pd.read_csv('website_access_category.csv')

top_30_countries = df_product_detail.head(50)
plt.figure(figsize=(25, 9))

# Create column charts with new customizations
plt.bar(
    top_30_countries['Category'],
    top_30_countries['Stock'],
    color='yellow',
    edgecolor='black',
    linewidth=1.2
)
plt.xlabel('Category', fontsize=16, fontweight='bold', color='darkblue')
plt.ylabel('Stock', fontsize=16, fontweight='bold', color='darkblue')
plt.title('Top 30 Category by Stock', fontsize=20, fontweight='bold', color='navy')
plt.xticks(rotation=45, ha='right', fontsize=14, color='darkblue')
plt.yticks(fontsize=14, color='darkblue')
plt.grid(True, linestyle='--', color='gray', alpha=0.6, axis='y')
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
df_customer_table = pd.read_csv('customer_table.csv')
df_market_trend = pd.read_csv('market_trend.csv')
df_product_detail = pd.read_csv('product_detail.csv')
df_sale_table = pd.read_csv('sale_table.csv')
df_website_access_category = pd.read_csv('website_access_category.csv')
# Drawing bijou map (example)
plt.figure(figsize=(12, 8))
plt.plot([1, 2, 3], [4, 5, 6])
plt.title('Example Plot')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.show()
